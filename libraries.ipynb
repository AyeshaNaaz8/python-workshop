# %% [markdown]
# <a href="https://colab.research.google.com/github/AyeshaNaaz8/python-workshop/blob/main/libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("880D_mart_data.xlsx")

# %%
df.head()
# Out:
#         DATE PRODUCT ID  QUANTITY     SALE TYPE    LOCATION PAYMENT MODE  \
# 0 2021-01-01      P0024         9    Wholesaler     Alabama       Online
# 1 2021-01-02      P0038        15        Online     Alabama         Cash
# 2 2021-01-02      P0013         6  Direct Sales     Arizona         Cash
# 3 2021-01-03      P0004         5  Direct Sales     Arizona       Online
# 4 2021-01-04      P0035        12        Online  California       Online
#
#      PRODUCT    CATEGORY  UOM  PURCHASE PRICE  SALE PRICE  PURCHASES AMOUNT  \
# 0  Product24  Category03   Ft             144      156.96              1296
# 1  Product38  Category05   Kg              72       79.92              1080
# 2  Product13  Category02   Kg             112      122.08               672
# 3  Product04  Category01   Lt              44       48.84               220
# 4  Product35  Category04  No.               5        6.70                60
#
#    SALES AMOUNT
# 0       1412.64
# 1       1198.80
# 2        732.48
# ...

# %%
df.shape
# Out:
# (527, 13)

# %%
df.dtypes
# Out:
# DATE                datetime64[ns]
# PRODUCT ID                  object
# QUANTITY                     int64
# SALE TYPE                   object
# LOCATION                    object
# PAYMENT MODE                object
# PRODUCT                     object
# CATEGORY                    object
# UOM                         object
# PURCHASE PRICE               int64
# SALE PRICE                 float64
# PURCHASES AMOUNT             int64
# SALES AMOUNT               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# DATE                0
# PRODUCT ID          0
# QUANTITY            0
# SALE TYPE           0
# LOCATION            0
# PAYMENT MODE        0
# PRODUCT             0
# CATEGORY            0
# UOM                 0
# PURCHASE PRICE      0
# SALE PRICE          0
# PURCHASES AMOUNT    0
# SALES AMOUNT        0
# dtype: int64

# %%
df.sample(10)
# Out:
#           DATE PRODUCT ID  QUANTITY     SALE TYPE      LOCATION PAYMENT MODE  \
# 118 2021-06-05      P0035        10  Direct Sales    California       Online
# 54  2021-03-08      P0044         9        Online      Nebraska       Online
# 373 2022-05-30      P0044         9  Direct Sales  Pennsylvania       Online
# 298 2022-02-16      P0032         1        Online          Utah         Cash
# 215 2021-10-12      P0027         8        Online    California       Online
# 128 2021-06-16      P0039        11  Direct Sales    California         Cash
# 86  2021-04-15      P0017         3  Direct Sales         Texas       Online
# 238 2021-11-27      P0012         8        Online      Illinois       Online
# 266 2022-01-03      P0043         9  Direct Sales      New York         Cash
# 277 2022-01-18      P0008         9    Wholesaler  Pennsylvania         Cash
#
#        PRODUCT    CATEGORY  UOM  PURCHASE PRICE  SALE PRICE  PURCHASES AMOUNT  \
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'PRODUCT ID', 'QUANTITY', 'SALE TYPE', 'LOCATION',
#        'PAYMENT MODE', 'PRODUCT', 'CATEGORY', 'UOM', 'PURCHASE PRICE',
#        'SALE PRICE', 'PURCHASES AMOUNT', 'SALES AMOUNT'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527 entries, 0 to 526
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATE              527 non-null    datetime64[ns]
#  1   PRODUCT ID        527 non-null    object
#  2   QUANTITY          527 non-null    int64
#  3   SALE TYPE         527 non-null    object
#  4   LOCATION          527 non-null    object
#  5   PAYMENT MODE      527 non-null    object
#  6   PRODUCT           527 non-null    object
#  7   CATEGORY          527 non-null    object
#  8   UOM               527 non-null    object
#  9   PURCHASE PRICE    527 non-null    int64
#  10  SALE PRICE        527 non-null    float64
#  11  PURCHASES AMOUNT  527 non-null    int64
#  12  SALES AMOUNT      527 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(7)
# memory usage: 53.6+ KB

# %%
df.hist(figsize=(10,20))
plt.show()

# %%
sns.distplot(df["SALES AMOUNT"])
# Out:
# <ipython-input-19-4bb4f9174295>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["SALES AMOUNT"])
# <Axes: xlabel='SALES AMOUNT', ylabel='Density'>

# %%
sns.distplot(df["SALE PRICE"])
# Out:
# <ipython-input-21-87b84806900e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["SALE PRICE"])
# <Axes: xlabel='SALE PRICE', ylabel='Density'>
